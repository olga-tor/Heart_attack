# %% [markdown]
# # Мастерская. Проект по предсказанию сердечного приступа.

# %% [markdown]
# В данном проекте нам предстоит нам предстоит разработать модель машинного обучния, а также подготовить библиотеку и интерфейс к ней для предсказания на тестовой выборке.
#
# В начале проекта нам доступен обучающий датасет и тестовый датасет, не содержащий правильных ответов. Метрика на тестовом датасете будет измерена в ходе проверки работы. Также нам доступен скрипт, с помощью которого будет измеряться финальная метрика вашей модели.
#
# В данной работе мы сделаем следующие шаги:
# - изучим предоставленные данные,
# - проведем предобработку,
# - исследования,
# - объединение данных и выделение необходимых признаков,
# - изучим взаимосвязь параметров между собой,
# - построим модели,
# - подобрем гипермараметры,
# - выберем наиболее подходящую из них,
# - подберем наиболее подходящую для проекта метрику,
# - сделаем предсказание для тестовой выборки для отправки на проверку,
# - кроме того, мы подготовим библиотеку и интерфейс к ней.

# %%
#импорты и константы

import numpy as np
import pandas as pd
import re
# !pip install --upgrade matplotlib -q
import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as st
# !pip install --upgrade scikit-learn -q
from sklearn.model_selection import train_test_split

# !pip install xgboost -q
# !pip install lightgbm -q
# !pip install catboost -q

# !pip install scikit-learn -q
from sklearn.pipeline import Pipeline

# загружаем классы для подготовки данных
from sklearn.preprocessing import (
    OneHotEncoder,
    StandardScaler, 
    MinMaxScaler,
    LabelEncoder
)
from sklearn.compose import ColumnTransformer

# загружаем функцию для работы с метриками
from sklearn.metrics import (accuracy_score, f1_score, roc_auc_score,
                            classification_report, recall_score, precision_score,
                            fbeta_score, make_scorer)

from sklearn.metrics import confusion_matrix


from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# загружаем нужные модели
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import cross_val_score

# !pip install phik -q
from phik import phik_matrix
from phik.report import plot_correlation_matrix


# !pip install shap -q
import shap

RANDOM_STATE = 42
TEST_SIZE = 0.25

import warnings
#warnings.filterwarnings('ignore', category=FutureWarning)

# %% [markdown]
# ## Загрузка данных
#
# В начале работы загрузим и изучим данные.

# %%
# функция для изучения данных
def describe_db(name):
    print(name.info())
    display(name.shape)
    display(name.head())
    print('Дубликаты:', name.duplicated().sum())
    print()
    print('Пропуски:')
    print(name.isna().sum())
    print()

# %%
train_X_y = pd.read_csv('./heart_train.csv')
describe_db(train_X_y)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8685 entries, 0 to 8684
# Data columns (total 28 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       8685 non-null   int64
#  1   Age                              8685 non-null   float64
#  2   Cholesterol                      8685 non-null   float64
#  3   Heart rate                       8685 non-null   float64
#  4   Diabetes                         8442 non-null   float64
#  5   Family History                   8442 non-null   float64
#  6   Smoking                          8442 non-null   float64
#  7   Obesity                          8442 non-null   float64
#  8   Alcohol Consumption              8442 non-null   float64
#  9   Exercise Hours Per Week          8685 non-null   float64
#  10  Diet                             8685 non-null   int64
#  11  Previous Heart Problems          8442 non-null   float64
#  12  Medication Use                   8442 non-null   float64
#  13  Stress Level                     8442 non-null   float64
#  14  Sedentary Hours Per Day          8685 non-null   float64
#  15  Income                           8685 non-null   float64
#  16  BMI                              8685 non-null   float64
#  17  Triglycerides                    8685 non-null   float64
#  18  Physical Activity Days Per Week  8442 non-null   float64
#  19  Sleep Hours Per Day              8685 non-null   float64
#  20  Heart Attack Risk (Binary)       8685 non-null   float64
#  21  Blood sugar                      8685 non-null   float64
#  22  CK-MB                            8685 non-null   float64
#  23  Troponin                         8685 non-null   float64
#  24  Gender                           8685 non-null   object
#  25  Systolic blood pressure          8685 non-null   float64
#  26  Diastolic blood pressure         8685 non-null   float64
#  27  id                               8685 non-null   int64
# dtypes: float64(24), int64(3), object(1)
# memory usage: 1.9+ MB
# None
# (8685, 28)
#    Unnamed: 0       Age  Cholesterol  Heart rate  Diabetes  Family History  \
# 0           0  0.359551     0.732143    0.074244       1.0             1.0
# 1           1  0.202247     0.325000    0.047663       1.0             1.0
# 2           2  0.606742     0.860714    0.055912       1.0             0.0
# 3           3  0.730337     0.007143    0.053162       0.0             0.0
# 4           4  0.775281     0.757143    0.021998       0.0             0.0
#
#    Smoking  Obesity  Alcohol Consumption  Exercise Hours Per Week  ...  \
# 0      1.0      1.0                  1.0                 0.535505  ...
# 1      0.0      0.0                  1.0                 0.068690  ...
# 2      1.0      1.0                  1.0                 0.944001  ...
# 3      1.0      0.0                  1.0                 0.697023  ...
# 4      1.0      0.0                  1.0                 0.412878  ...
#
#    Physical Activity Days Per Week  Sleep Hours Per Day  \
# 0                              3.0             0.333333
# 1                              3.0             0.833333
# 2                              2.0             1.000000
# 3                              0.0             0.333333
# 4                              5.0             1.000000
#
#    Heart Attack Risk (Binary)  Blood sugar     CK-MB  Troponin  Gender  \
# 0                         0.0     0.227018  0.048229  0.036512    Male
# 1                         0.0     0.150198  0.017616  0.000194  Female
# 2                         0.0     0.227018  0.048229  0.036512  Female
# 3                         1.0     0.227018  0.048229  0.036512  Female
# 4                         1.0     0.227018  0.048229  0.036512    Male
#
#    Systolic blood pressure  Diastolic blood pressure    id
# 0                 0.212903                  0.709302  2664
# 1                 0.412903                  0.569767  9287
# 2                 0.238710                  0.220930  5379
# 3                 0.348387                  0.267442  8222
# 4                 0.619355                  0.441860  4047
#
# [5 rows x 28 columns]
# Дубликаты: 0
#
# Пропуски:
# Unnamed: 0                           0
# Age                                  0
# Cholesterol                          0
# Heart rate                           0
# Diabetes                           243
# Family History                     243
# Smoking                            243
# Obesity                            243
# Alcohol Consumption                243
# Exercise Hours Per Week              0
# Diet                                 0
# Previous Heart Problems            243
# Medication Use                     243
# Stress Level                       243
# Sedentary Hours Per Day              0
# Income                               0
# BMI                                  0
# Triglycerides                        0
# Physical Activity Days Per Week    243
# Sleep Hours Per Day                  0
# Heart Attack Risk (Binary)           0
# Blood sugar                          0
# CK-MB                                0
# Troponin                             0
# Gender                               0
# Systolic blood pressure              0
# Diastolic blood pressure             0
# id                                   0
# dtype: int64

# %%
test_X_y = pd.read_csv('./heart_test.csv')
describe_db(test_X_y)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 966 entries, 0 to 965
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       966 non-null    int64
#  1   Age                              966 non-null    float64
#  2   Cholesterol                      966 non-null    float64
#  3   Heart rate                       966 non-null    float64
#  4   Diabetes                         935 non-null    float64
#  5   Family History                   935 non-null    float64
#  6   Smoking                          935 non-null    float64
#  7   Obesity                          935 non-null    float64
#  8   Alcohol Consumption              935 non-null    float64
#  9   Exercise Hours Per Week          966 non-null    float64
#  10  Diet                             966 non-null    int64
#  11  Previous Heart Problems          935 non-null    float64
#  12  Medication Use                   935 non-null    float64
#  13  Stress Level                     935 non-null    float64
#  14  Sedentary Hours Per Day          966 non-null    float64
#  15  Income                           966 non-null    float64
#  16  BMI                              966 non-null    float64
#  17  Triglycerides                    966 non-null    float64
#  18  Physical Activity Days Per Week  935 non-null    float64
#  19  Sleep Hours Per Day              966 non-null    float64
#  20  Blood sugar                      966 non-null    float64
#  21  CK-MB                            966 non-null    float64
#  22  Troponin                         966 non-null    float64
#  23  Gender                           966 non-null    object
#  24  Systolic blood pressure          966 non-null    float64
#  25  Diastolic blood pressure         966 non-null    float64
#  26  id                               966 non-null    int64
# dtypes: float64(23), int64(3), object(1)
# memory usage: 203.9+ KB
# None
# (966, 27)
#    Unnamed: 0       Age  Cholesterol  Heart rate  Diabetes  Family History  \
# 0           0  0.494382     0.264286    0.062328       0.0             1.0
# 1           1  0.224719     0.953571    0.082493       1.0             0.0
# 2           2  0.629213     0.092857    0.064161       0.0             1.0
# 3           3  0.460674     0.567857    0.055912       1.0             1.0
# 4           4  0.719101     0.485714    0.022915       1.0             0.0
#
#    Smoking  Obesity  Alcohol Consumption  Exercise Hours Per Week  ...  \
# 0      1.0      1.0                  1.0                 0.361618  ...
# 1      0.0      1.0                  0.0                 0.996483  ...
# 2      1.0      1.0                  0.0                 0.995561  ...
# 3      1.0      1.0                  1.0                 0.437277  ...
# 4      1.0      0.0                  1.0                 0.514920  ...
#
#    Triglycerides  Physical Activity Days Per Week  Sleep Hours Per Day  \
# 0       0.306494                              1.0             0.333333
# 1       0.087013                              0.0             0.166667
# 2       0.205195                              7.0             1.000000
# 3       0.163636                              0.0             0.666667
# 4       0.580519                              5.0             0.000000
#
#    Blood sugar     CK-MB  Troponin  Gender  Systolic blood pressure  \
# 0     0.227018  0.048229  0.036512    Male                 0.283871
# 1     0.227018  0.048229  0.036512  Female                 0.703226
# 2     0.102767  0.002666  0.088455    Male                 0.458065
# 3     0.203557  0.056390  0.271774  Female                 0.741935
# 4     0.227018  0.048229  0.036512    Male                 0.412903
#
#    Diastolic blood pressure    id
# 0                  0.372093  7746
# 1                  0.441860  4202
# 2                  0.779070  6632
# 3                  0.255814  4639
# 4                  0.395349  4825
#
# [5 rows x 27 columns]
# Дубликаты: 0
#
# Пропуски:
# Unnamed: 0                          0
# Age                                 0
# Cholesterol                         0
# Heart rate                          0
# Diabetes                           31
# Family History                     31
# Smoking                            31
# Obesity                            31
# Alcohol Consumption                31
# Exercise Hours Per Week             0
# Diet                                0
# Previous Heart Problems            31
# Medication Use                     31
# Stress Level                       31
# Sedentary Hours Per Day             0
# Income                              0
# BMI                                 0
# Triglycerides                       0
# Physical Activity Days Per Week    31
# Sleep Hours Per Day                 0
# Blood sugar                         0
# CK-MB                               0
# Troponin                            0
# Gender                              0
# Systolic blood pressure             0
# Diastolic blood pressure            0
# id                                  0
# dtype: int64

# %% [markdown]
# Самое заметное в данных - они масштабированы. Скорее всего - в целях конфиденциальности. Так же скрыты и личные данные пациентов.
#
# В данных тренировочных и тестовых наблюдаются колонки с неверными типами данных (float для целочисленных, скорее всего, колонок). Полных дубликатов не наблюдается, есть пропуски, в одинаковом количестве для разных столбцов. Предполагаю, что они возникли из-за отсутствия данных, а не из-за ошибок. Данных получено достаточно много: почти 9000 на обучение и почти 1000 значений в тестовой выборке. Предполагаю, что этого должно хватить на качественное обучение модели.
#
# В целом, присутствует очень много колонок с различными характеристиками. В дальнейшем вникнем в их содержание, поправим форматы, примем решение по пропускам, исключим колонки, которые будут неверно влиять на обучение (скорее всего, под такое исключение попадет колонка с номером пациента, id и возможные утечки данных). Править мы будем только тренировочные данные, тестовые останутся без изменений.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Для начала заменим названия столбцов на более корректно написанные

# %%
def to_snake_case(column_name):
    s1 = re.sub('(.)([A-Z][a-z]+)', r'\1\2', column_name)
    s2 = re.sub(r'[ ]+', '_', s1)
    return s2.lower().strip('_')

train_X_y.columns = [to_snake_case(col) for col in train_X_y.columns]

print(train_X_y.columns)
# Out:
# Index(['unnamed:_0', 'age', 'cholesterol', 'heart_rate', 'diabetes',
#        'family_history', 'smoking', 'obesity', 'alcohol_consumption',
#        'exercise_hours_per_week', 'diet', 'previous_heart_problems',
#        'medication_use', 'stress_level', 'sedentary_hours_per_day', 'income',
#        'bmi', 'triglycerides', 'physical_activity_days_per_week',
#        'sleep_hours_per_day', 'heart_attack_risk_(binary)', 'blood_sugar',
#        'ck-mb', 'troponin', 'gender', 'systolic_blood_pressure',
#        'diastolic_blood_pressure', 'id'],
#       dtype='object')

# %% [markdown]
# Как уже выяснили выше, полных дубликатов в таблицах не обнаружено. Попробуем проверить, что будет, если исключить столбцы Unnamed и id из таблиц. Для начала проверим количество уникальных значений в этих столбцах.

# %%
def count_unique(column):
    print(column.name)
    print(len(column.unique()))

# %%
count_unique(train_X_y['unnamed:_0'])
count_unique(train_X_y['id'])
# Out:
# unnamed:_0
# 8685
# id
# 8685

# %% [markdown]
# Видно, что нет дубликатов и пропусков в этих столбцах. Значит, эти значения уникальны и привязаны к каждому отдельному пациенту. Они могут негативно повлиять на обучение, например, если каким-то образом пациенты записаны не в случайном порядке, а сначала те, у кого был сердечный приступ, а потом те, у кого не было. Один столбец удалим сейчас, другой позже, пока оставим для удобства использования функций в исследовательском анализе данных.

# %%
train_X_y = train_X_y.drop(['unnamed:_0'], axis=1)
describe_db(train_X_y)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8685 entries, 0 to 8684
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              8685 non-null   float64
#  1   cholesterol                      8685 non-null   float64
#  2   heart_rate                       8685 non-null   float64
#  3   diabetes                         8442 non-null   float64
#  4   family_history                   8442 non-null   float64
#  5   smoking                          8442 non-null   float64
#  6   obesity                          8442 non-null   float64
#  7   alcohol_consumption              8442 non-null   float64
#  8   exercise_hours_per_week          8685 non-null   float64
#  9   diet                             8685 non-null   int64
#  10  previous_heart_problems          8442 non-null   float64
#  11  medication_use                   8442 non-null   float64
#  12  stress_level                     8442 non-null   float64
#  13  sedentary_hours_per_day          8685 non-null   float64
#  14  income                           8685 non-null   float64
#  15  bmi                              8685 non-null   float64
#  16  triglycerides                    8685 non-null   float64
#  17  physical_activity_days_per_week  8442 non-null   float64
#  18  sleep_hours_per_day              8685 non-null   float64
#  19  heart_attack_risk_(binary)       8685 non-null   float64
#  20  blood_sugar                      8685 non-null   float64
#  21  ck-mb                            8685 non-null   float64
#  22  troponin                         8685 non-null   float64
#  23  gender                           8685 non-null   object
#  24  systolic_blood_pressure          8685 non-null   float64
#  25  diastolic_blood_pressure         8685 non-null   float64
#  26  id                               8685 non-null   int64
# dtypes: float64(24), int64(2), object(1)
# memory usage: 1.8+ MB
# None
# (8685, 27)
#         age  cholesterol  heart_rate  diabetes  family_history  smoking  \
# 0  0.359551     0.732143    0.074244       1.0             1.0      1.0
# 1  0.202247     0.325000    0.047663       1.0             1.0      0.0
# 2  0.606742     0.860714    0.055912       1.0             0.0      1.0
# 3  0.730337     0.007143    0.053162       0.0             0.0      1.0
# 4  0.775281     0.757143    0.021998       0.0             0.0      1.0
#
#    obesity  alcohol_consumption  exercise_hours_per_week  diet  ...  \
# 0      1.0                  1.0                 0.535505     1  ...
# 1      0.0                  1.0                 0.068690     2  ...
# 2      1.0                  1.0                 0.944001     2  ...
# 3      0.0                  1.0                 0.697023     0  ...
# 4      0.0                  1.0                 0.412878     1  ...
#
#    physical_activity_days_per_week  sleep_hours_per_day  \
# 0                              3.0             0.333333
# 1                              3.0             0.833333
# 2                              2.0             1.000000
# 3                              0.0             0.333333
# 4                              5.0             1.000000
#
#    heart_attack_risk_(binary)  blood_sugar     ck-mb  troponin  gender  \
# 0                         0.0     0.227018  0.048229  0.036512    Male
# 1                         0.0     0.150198  0.017616  0.000194  Female
# 2                         0.0     0.227018  0.048229  0.036512  Female
# 3                         1.0     0.227018  0.048229  0.036512  Female
# 4                         1.0     0.227018  0.048229  0.036512    Male
#
#    systolic_blood_pressure  diastolic_blood_pressure    id
# 0                 0.212903                  0.709302  2664
# 1                 0.412903                  0.569767  9287
# 2                 0.238710                  0.220930  5379
# 3                 0.348387                  0.267442  8222
# 4                 0.619355                  0.441860  4047
#
# [5 rows x 27 columns]
# Дубликаты: 0
#
# Пропуски:
# age                                  0
# cholesterol                          0
# heart_rate                           0
# diabetes                           243
# family_history                     243
# smoking                            243
# obesity                            243
# alcohol_consumption                243
# exercise_hours_per_week              0
# diet                                 0
# previous_heart_problems            243
# medication_use                     243
# stress_level                       243
# sedentary_hours_per_day              0
# income                               0
# bmi                                  0
# triglycerides                        0
# physical_activity_days_per_week    243
# sleep_hours_per_day                  0
# heart_attack_risk_(binary)           0
# blood_sugar                          0
# ck-mb                                0
# troponin                             0
# gender                               0
# systolic_blood_pressure              0
# diastolic_blood_pressure             0
# id                                   0
# dtype: int64

# %% [markdown]
# Дубликатов нет даже после удаления ненужных столбцов. Теперь проверим содержимое единственного текстового столбца Gender.

# %%
train_X_y['gender'].unique()
# Out:
# array(['Male', 'Female', '1.0', '0.0'], dtype=object)

# %% [markdown]
# Опечаток нет, но мужской и женский пол для некоторых значений заменены на 1 и 0, соответственно. Сделаем эти значения единообразными.

# %%
train_X_y['gender'] = train_X_y['gender'].replace({'Female': 0.0, 'Male': 1.0}).astype(float).astype(int)

train_X_y['gender'].unique()
# Out:
# array([1, 0])

# %% [markdown]
# Заменим типы данных и для других столбцов c целыми числами, заодно заменим пропуски на значение -1. Заменять пропуски средними или наиболее частыми значениями мы не будем, так как это живые данные и не стоит выдумывать тут свои числа.

# %%
train_X_y.nunique()
# Out:
# age                                  77
# cholesterol                         282
# heart_rate                           87
# diabetes                              2
# family_history                        2
# smoking                               2
# obesity                               2
# alcohol_consumption                   2
# exercise_hours_per_week            7933
# diet                                  4
# previous_heart_problems               2
# medication_use                        2
# stress_level                         10
# sedentary_hours_per_day            7933
# income                             7808
# bmi                                7933
# triglycerides                       772
# physical_activity_days_per_week       8
# sleep_hours_per_day                   8
# heart_attack_risk_(binary)            2
# blood_sugar                         239
# ck-mb                               679
# troponin                            340
# gender                                2
# systolic_blood_pressure             100
# diastolic_blood_pressure             66
# id                                 8685
# dtype: int64

# %%
train_X_y['stress_level'].unique()
# Out:
# array([ 8.,  9.,  6.,  3.,  7.,  1., 10., nan,  2.,  5.,  4.])

# %%
train_X_y['sleep_hours_per_day'].unique()
# Out:
# array([0.33333333, 0.83333333, 1.        , 0.        , 0.16666667,
#        0.66666667, 0.50462124, 0.5       ])

# %%
for column in train_X_y.columns:
    if len(train_X_y[column].unique()) <= 11 and column!='sleep_hours_per_day':
        train_X_y[column] = train_X_y[column].fillna(-1).astype('int64')

# %%
train_X_y['sleep_hours_per_day'] = train_X_y['sleep_hours_per_day'].round(2)

# %%
describe_db(train_X_y)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8685 entries, 0 to 8684
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              8685 non-null   float64
#  1   cholesterol                      8685 non-null   float64
#  2   heart_rate                       8685 non-null   float64
#  3   diabetes                         8685 non-null   int64
#  4   family_history                   8685 non-null   int64
#  5   smoking                          8685 non-null   int64
#  6   obesity                          8685 non-null   int64
#  7   alcohol_consumption              8685 non-null   int64
#  8   exercise_hours_per_week          8685 non-null   float64
#  9   diet                             8685 non-null   int64
#  10  previous_heart_problems          8685 non-null   int64
#  11  medication_use                   8685 non-null   int64
#  12  stress_level                     8685 non-null   int64
#  13  sedentary_hours_per_day          8685 non-null   float64
#  14  income                           8685 non-null   float64
#  15  bmi                              8685 non-null   float64
#  16  triglycerides                    8685 non-null   float64
#  17  physical_activity_days_per_week  8685 non-null   int64
#  18  sleep_hours_per_day              8685 non-null   float64
#  19  heart_attack_risk_(binary)       8685 non-null   int64
#  20  blood_sugar                      8685 non-null   float64
#  21  ck-mb                            8685 non-null   float64
#  22  troponin                         8685 non-null   float64
#  23  gender                           8685 non-null   int64
#  24  systolic_blood_pressure          8685 non-null   float64
#  25  diastolic_blood_pressure         8685 non-null   float64
#  26  id                               8685 non-null   int64
# dtypes: float64(14), int64(13)
# memory usage: 1.8 MB
# None
# (8685, 27)
#         age  cholesterol  heart_rate  diabetes  family_history  smoking  \
# 0  0.359551     0.732143    0.074244         1               1        1
# 1  0.202247     0.325000    0.047663         1               1        0
# 2  0.606742     0.860714    0.055912         1               0        1
# 3  0.730337     0.007143    0.053162         0               0        1
# 4  0.775281     0.757143    0.021998         0               0        1
#
#    obesity  alcohol_consumption  exercise_hours_per_week  diet  ...  \
# 0        1                    1                 0.535505     1  ...
# 1        0                    1                 0.068690     2  ...
# 2        1                    1                 0.944001     2  ...
# 3        0                    1                 0.697023     0  ...
# 4        0                    1                 0.412878     1  ...
#
#    physical_activity_days_per_week  sleep_hours_per_day  \
# 0                                3                 0.33
# 1                                3                 0.83
# 2                                2                 1.00
# 3                                0                 0.33
# 4                                5                 1.00
#
#    heart_attack_risk_(binary)  blood_sugar     ck-mb  troponin  gender  \
# 0                           0     0.227018  0.048229  0.036512       1
# 1                           0     0.150198  0.017616  0.000194       0
# 2                           0     0.227018  0.048229  0.036512       0
# 3                           1     0.227018  0.048229  0.036512       0
# 4                           1     0.227018  0.048229  0.036512       1
#
#    systolic_blood_pressure  diastolic_blood_pressure    id
# 0                 0.212903                  0.709302  2664
# 1                 0.412903                  0.569767  9287
# 2                 0.238710                  0.220930  5379
# 3                 0.348387                  0.267442  8222
# 4                 0.619355                  0.441860  4047
#
# [5 rows x 27 columns]
# Дубликаты: 0
#
# Пропуски:
# age                                0
# cholesterol                        0
# heart_rate                         0
# diabetes                           0
# family_history                     0
# smoking                            0
# obesity                            0
# alcohol_consumption                0
# exercise_hours_per_week            0
# diet                               0
# previous_heart_problems            0
# medication_use                     0
# stress_level                       0
# sedentary_hours_per_day            0
# income                             0
# bmi                                0
# triglycerides                      0
# physical_activity_days_per_week    0
# sleep_hours_per_day                0
# heart_attack_risk_(binary)         0
# blood_sugar                        0
# ck-mb                              0
# troponin                           0
# gender                             0
# systolic_blood_pressure            0
# diastolic_blood_pressure           0
# id                                 0
# dtype: int64

# %% [markdown]
# Таким образом, мы изменили типы данных с столбцах с целыми значениями, исправили разнообразие в формате записи значений столбца Gender, заменили пропуски на значения -1. Так же удалили столбцы, не имеющие отношение к обучению модели. После всех этих действий дубликатов не появилось. Далее, мы проведем исследовательский анализ данных и постараемся исключить значения, которые являются утечкой данных.

# %% [markdown]
# ## Исследовательский анализ  данных

# %%
# Функция для категориальных данных, круговая диаграмма
def categ_pieplot(df, col, title):
    display(df.groupby(col)['id'].count())
    (df[col].value_counts().plot.pie(y='id',autopct='%1.0f%%'))
    plt.title(title);
    
# Функция для количественных данных, гистограмма
def col_hist(df, col, title, label, bins=200):
    print(f"\n{title} - описательная статистика:")
    print(df[col].describe());
    
    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16,6))
    fig.suptitle(f"{title}", fontsize=15)
    sns.histplot(df[col], bins = bins, ax=ax[0]);
    ax[0].set_title('Гистограмма');
    ax[0].set_xlabel(label);
    ax[0].set_ylabel('Количество пациентов');
    
    sns.boxplot(df[col], ax=ax[1])
    ax[1].set_title('Boxplot', fontsize=15)
    ax[1].set_xlabel(None)
    plt.show()
    
# Функция для количественных данных, дискретные

def col_count(df, col, title, label):
    print(f"\n{title} - описательная статистика:")
    print(df[col].describe())
    
    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))
    fig.suptitle(title, fontsize=15, y=1.05)
    
    counts = df[col].value_counts().sort_index()
    sns.barplot(x=counts.index, y=counts.values, ax=ax1, 
                hue=counts.index, palette='viridis', legend=False)
    
    ax1.set_title('Распределение значений', fontsize=13)
    ax1.set_xlabel(label)
    ax1.set_ylabel('Количество пациентов')
    ax1.tick_params(axis='x', rotation=45 if len(counts) > 5 else 0)
    
    sns.boxplot(x=df[col], ax=ax2, color='skyblue', showfliers=True)
    ax2.set_title('Boxplot', fontsize=13)
    ax2.set_xlabel(label)
    
    plt.tight_layout()
    plt.show()
    
    print(f"\nУникальные значения ({len(df[col].unique())}):")
    print(df[col].value_counts().sort_index())

# %% [markdown]
# ### Возраст

# %%
col_hist(train_X_y, 'age', 'Возраст пациентов', 'Возраст, масштабированный')
# Out:
# Возраст пациентов - описательная статистика:
# count    8685.000000
# mean        0.449958
# std         0.231174
# min         0.000000
# 25%         0.258427
# 50%         0.460674
# 75%         0.640449
# max         1.000000
# Name: age, dtype: float64

# %% [markdown]
# Возраст пациентов распределен достаточно равномерно с несколькими заметными пиками примерно на середине значений. Среднее значение очень близко к медианному. Есть малое количество значений около 0 и ближе к 1, чем основная масса. Скорее всего, это не ошибочные данные (до масштабирования), а редкие пациенты долгожители (около 1) или очень молодые (около 0). Удивительно, что между значениями околоо 0,85 и 1 такие большие пропуски, так что все-таки не исключена возможность ошибки, однако, оставим эти данные.

# %% [markdown]
# ### Холестерин

# %%
col_hist(train_X_y, 'cholesterol', 'Холестерин', 'Холестерин, масштабированный')
# Out:
# Холестерин - описательная статистика:
# count    8685.000000
# mean        0.501070
# std         0.284716
# min         0.000000
# 25%         0.267857
# 50%         0.499780
# 75%         0.746429
# max         1.000000
# Name: cholesterol, dtype: float64

# %% [markdown]
# В значениях холестерина резко выделяется один пик. Возможно, это связано с округлением значения при сборе анализов. Например, если значение попало в референс нормальных значений 3.6–5.2 ммоль/л, то в такой ситуации могут записать не конкретное значение, а отметить норму и как значение может быть записано только одно из этих чисел.
#
# В остальном, значения распределены с пиками (тоже, возможно, округление), но равномерно.

# %% [markdown]
# ### Пульс

# %%
col_hist(train_X_y, 'heart_rate', 'Пульс', 'Пульс, масштабированный')
# Out:
# Пульс - описательная статистика:
# count    8685.000000
# mean        0.050658
# std         0.023453
# min         0.000000
# 25%         0.034830
# 50%         0.050412
# 75%         0.065995
# max         1.000000
# Name: heart_rate, dtype: float64

# %% [markdown]
# Есть очень заметный выброс на значении 1.0

# %%
train_X_y[train_X_y['heart_rate']==1.0]
# Out:
#            age  cholesterol  heart_rate  diabetes  family_history  smoking  \
# 1377  0.629213      0.49978         1.0        -1              -1       -1
# 2712  0.202247      0.49978         1.0        -1              -1       -1
#
#       obesity  alcohol_consumption  exercise_hours_per_week  diet  ...  \
# 1377       -1                   -1                  0.50211     3  ...
# 2712       -1                   -1                  0.50211     3  ...
#
#       physical_activity_days_per_week  sleep_hours_per_day  \
# 1377                               -1                  0.5
# 2712                               -1                  0.5
#
#       heart_attack_risk_(binary)  blood_sugar     ck-mb  troponin  gender  \
# 1377                           0     0.203557  0.011843  0.002622       0
# 2712                           0     0.092885  0.007805  0.000680       0
#
#       systolic_blood_pressure  diastolic_blood_pressure    id
# 1377                 0.490323                  0.616279  9547
# 2712                 0.490323                  0.616279  9611
#
# [2 rows x 27 columns]

# %% [markdown]
# Значение 1.0 повторяется дважды, часть других параметров совпадает, часть различается. Целевой параметр heart_attack_risk_(binary) равен 0 в обоих случаях. Так как сомнительное значение пульса встречается всего дважды, при этом медианное значение равно 0.05, а стандартное отклонение равно 0.02, данные значения исключим из базы данных. Предполагается какая-то ошибка, такая разница пульса не может быть даже если учитывать возможность физической нагрузки. При подготовке данных перед обучением модели мы снова масштабируем значения.

# %%
train_X_y = train_X_y[train_X_y['heart_rate'] != 1.0]

# %%
col_hist(train_X_y, 'heart_rate', 'Пульс', 'Пульс, масштабированный')
# Out:
# Пульс - описательная статистика:
# count    8683.000000
# mean        0.050439
# std         0.018507
# min         0.000000
# 25%         0.034830
# 50%         0.050412
# 75%         0.065995
# max         0.105408
# Name: heart_rate, dtype: float64

# %% [markdown]
# Теперь значения распределены более адекватно. На меньших и больших значениях встречаются более редкие значения, что вполне объяснимо для граничных значений.

# %% [markdown]
# ### Диабет

# %%
categ_pieplot(train_X_y, 'diabetes', 'Диабет')
# Out:
# diabetes
# -1     241
#  0    2937
#  1    5505
# Name: id, dtype: int64

# %% [markdown]
# У большинства пациентов (63%) был диагностирован диабет. 34% не имеют диабета, а 3% - пропущенные значения. Скорее всего, большое количество людей с диабетом связано с тем, что люди с хроническими болезнями чаще обследуются, чем те, кто ощущает себя здоровыми.

# %% [markdown]
# ### Семейная история

# %%
categ_pieplot(train_X_y, 'family_history', 'Семейная история')
# Out:
# family_history
# -1     241
#  0    4309
#  1    4133
# Name: id, dtype: int64

# %% [markdown]
# Пациенты распределились почти пополам. Вероятнее всего, под этим признаком подразумевается наличие сердечных приступов в семейном анамнезе. Возможно, этот признак будет очень сильно влиять на целевой, посмотрим и решим в корреляционном анализе.

# %% [markdown]
# ### Курение

# %%
categ_pieplot(train_X_y, 'smoking', 'Курение')
# Out:
# smoking
# -1     241
#  0     820
#  1    7622
# Name: id, dtype: int64

# %% [markdown]
# Подавляющее большинство (88%) пациентов курит. Данные кажутся немного искаженными, но какие есть. Возможно, значение 1, вопреки ожидаемому, означает наоборот "не курит", тогда значения больше похоже на правду, если предположить, что не все пациенты признаются в этой привычке.

# %% [markdown]
# ### Ожирение

# %%
categ_pieplot(train_X_y, 'obesity', 'Ожирение')
# Out:
# obesity
# -1     241
#  0    4235
#  1    4207
# Name: id, dtype: int64

# %% [markdown]
# Ожирение среди клиентов распределено одинаково: 50% значений говорит о наличии ожирение и 50% об отсутствии ожирения.

# %% [markdown]
# ### Алкоголь

# %%
categ_pieplot(train_X_y, 'alcohol_consumption', 'Употребление алкоголя')
# Out:
# alcohol_consumption
# -1     241
#  0    3360
#  1    5082
# Name: id, dtype: int64

# %% [markdown]
# 59% пациентов признают употребление алкоголя, 39% отрицают. Никаких интересных значений.

# %% [markdown]
# ### Упражнения в неделю

# %%
col_hist(train_X_y, 'exercise_hours_per_week', 'Количество часов нагрузки в неделю', 'часов, масштаб.')
# Out:
# Количество часов нагрузки в неделю - описательная статистика:
# count    8683.000000
# mean        0.503378
# std         0.284843
# min         0.000000
# 25%         0.263219
# 50%         0.502110
# 75%         0.748709
# max         1.000000
# Name: exercise_hours_per_week, dtype: float64

# %% [markdown]
# Как и в случае с холестерином, здесь имеется очень высокий пик на одном значении. Остальные значения распределены достаточно равномерно. Пик, скорее всего, так же обусловлен каким-то особенным сбором данных изначально. Возможно, в этом значении идет какая-то минимальная норма и именно для этих пациентов опрос был про ее выполнение, а не про реальное количество часов нагрузки. Интересно, что остальные значения так плотно распределены. Не очень понятно, как могло собраться такое равномерное разнообразие значений.

# %% [markdown]
# ### Диета

# %%
categ_pieplot(train_X_y, 'diet', 'Диета')
# Out:
# diet
# 0    2783
# 1    2863
# 2    2796
# 3     241
# Name: id, dtype: int64

# %% [markdown]
# Вероятно, этот параметр означает соблюдение пациентами какой-либо диеты. Обычно это является следствием каких-либо заболеваний либо предпочтений (если в этом параметре присутствует вегетариантсво). Пока не очень ясно, является ли это утечкой из-за диеты по каким-то кардиологическим заболеваниям или же речь идет о других диетах. Постараемся уловить эту связь с хроническими болезнями и целевым признаком.

# %%
train_X_y.pivot_table(index='diet', columns='diabetes', values='id', aggfunc='count')
# Out:
# diabetes     -1      0       1
# diet
# 0           NaN  982.0  1801.0
# 1           NaN  983.0  1880.0
# 2           NaN  972.0  1824.0
# 3         241.0    NaN     NaN

# %%
train_X_y.pivot_table(index='diet', columns='heart_attack_risk_(binary)', values='id', aggfunc='count')
# Out:
# heart_attack_risk_(binary)       0       1
# diet
# 0                           1813.0   970.0
# 1                           1805.0  1058.0
# 2                           1811.0   985.0
# 3                            241.0     NaN

# %%
train_X_y.pivot_table(index='diet', columns='medication_use', values='id', aggfunc='count')
# Out:
# medication_use     -1       0       1
# diet
# 0                 NaN  1383.0  1400.0
# 1                 NaN  1456.0  1407.0
# 2                 NaN  1372.0  1424.0
# 3               241.0     NaN     NaN

# %%
train_X_y.pivot_table(index='diet', columns='obesity', values='id', aggfunc='count')
# Out:
# obesity     -1       0       1
# diet
# 0          NaN  1379.0  1404.0
# 1          NaN  1442.0  1421.0
# 2          NaN  1414.0  1382.0
# 3        241.0     NaN     NaN

# %%
train_X_y.pivot_table(index='diet', columns='gender', values='id', aggfunc='count')
# Out:
# gender    0     1
# diet
# 0       832  1951
# 1       867  1996
# 2       861  1935
# 3        85   156

# %% [markdown]
# Сделать какие-то выводы довольно сложно, по таблицам не наблюдается связи ни с одни из рассмотренных параметров. Единственное, что обратило на себя внимание - это то что диета №3 присутствует только в тех записях, где очень много пропусков по другим параметрам. Так же, предполагаю, что диета №0 - это отсутствие соблюдения какой-то специальной диеты.
#
# Попробуем потом еще раз внимательно посмотреть на диету в корреляционном анализе. Сейчас еще раз посмотрим на значения с диетой номер 3.

# %%
train_X_y[train_X_y['diet']==3].sample(25)[['age', 'cholesterol', 'heart_rate', 'exercise_hours_per_week', 'sedentary_hours_per_day', 'income',
'bmi', 'triglycerides', 'blood_sugar', 'ck-mb',	'troponin', 'systolic_blood_pressure', 'diastolic_blood_pressure']]
# Out:
#            age  cholesterol  heart_rate  exercise_hours_per_week  \
# 2100  0.606742      0.49978    0.075160                  0.50211
# 5708  0.550562      0.49978    0.053162                  0.50211
# 6297  0.696629      0.49978    0.104491                  0.50211
# 2101  0.629213      0.49978    0.084326                  0.50211
# 913   0.617978      0.49978    0.048579                  0.50211
# 5344  0.550562      0.49978    0.040330                  0.50211
# 3844  0.471910      0.49978    0.045830                  0.50211
# 8392  0.516854      0.49978    0.073327                  0.50211
# 5221  0.797753      0.49978    0.084326                  0.50211
# 4978  0.516854      0.49978    0.104491                  0.50211
# 4873  0.629213      0.49978    0.073327                  0.50211
# 3950  0.382022      0.49978    0.053162                  0.50211
# 6315  0.438202      0.49978    0.053162                  0.50211
# 6381  0.471910      0.49978    0.048579                  0.50211
# 6588  0.808989      0.49978    0.036664                  0.50211
# 7299  0.348315      0.49978    0.088909                  0.50211
# 520   0.550562      0.49978    0.056829                  0.50211
# 6508  0.539326      0.49978    0.056829                  0.50211
# 5392  0.528090      0.49978    0.064161                  0.50211
# 1112  0.662921      0.49978    0.064161                  0.50211
# 4729  0.393258      0.49978    0.088909                  0.50211
# 2693  0.000000      0.49978    0.063245                  0.50211
# 3857  0.584270      0.49978    0.045830                  0.50211
# 4991  0.595506      0.49978    0.045830                  0.50211
# 592   0.235955      0.49978    0.049496                  0.50211
#
#       sedentary_hours_per_day    income       bmi  triglycerides  blood_sugar  \
# 2100                  0.49992  0.494889  0.494774       0.503603     0.466403
# 5708                  0.49992  0.494889  0.494774       0.503603     0.286561
# 6297                  0.49992  0.494889  0.494774       0.503603     0.112648
# 2101                  0.49992  0.494889  0.494774       0.503603     0.209486
# 913                   0.49992  0.494889  0.494774       0.503603     0.067194
# 5344                  0.49992  0.494889  0.494774       0.503603     0.152174
# 3844                  0.49992  0.494889  0.494774       0.503603     0.199605
# 8392                  0.49992  0.494889  0.494774       0.503603     0.320158
# 5221                  0.49992  0.494889  0.494774       0.503603     0.156126
# 4978                  0.49992  0.494889  0.494774       0.503603     0.252964
# 4873                  0.49992  0.494889  0.494774       0.503603     0.529644
# 3950                  0.49992  0.494889  0.494774       0.503603     0.124506
# 6315                  0.49992  0.494889  0.494774       0.503603     0.221344
# 6381                  0.49992  0.494889  0.494774       0.503603     0.424901
# 6588                  0.49992  0.494889  0.494774       0.503603     0.152174
# 7299                  0.49992  0.494889  0.494774       0.503603     0.330040
# 520                   0.49992  0.494889  0.494774       0.503603     0.118577
# 6508                  0.49992  0.494889  0.494774       0.503603     0.112648
# 5392                  0.49992  0.494889  0.494774       0.503603     0.241107
# 1112                  0.49992  0.494889  0.494774       0.503603     0.124506
# 4729                  0.49992  0.494889  0.494774       0.503603     0.227273
# 2693                  0.49992  0.494889  0.494774       0.503603     0.193676
# 3857                  0.49992  0.494889  0.494774       0.503603     0.456522
# 4991                  0.49992  0.494889  0.494774       0.503603     0.527668
# 592                   0.49992  0.494889  0.494774       0.503603     0.084980
#
#          ck-mb  troponin  systolic_blood_pressure  diastolic_blood_pressure
# 2100  0.007705  0.249442                 0.419355                  0.476744
# 5708  0.007538  0.000388                 0.329032                  0.209302
# 6297  0.006837  0.002913                 0.296774                  0.313953
# 2101  0.008606  0.005729                 0.322581                  0.313953
# 913   0.015447  0.000583                 0.451613                  0.453488
# 5344  0.338959  0.001554                 0.270968                  0.313953
# 3844  0.187097  0.003981                 0.245161                  0.197674
# 8392  0.010141  0.001068                 0.677419                  0.709302
# 5221  0.006237  0.005923                 0.322581                  0.313953
# 4978  0.009207  0.002330                 0.296774                  0.313953
# 4873  1.000000  0.001359                 0.670968                  0.569767
# 3950  0.014312  0.000485                 0.400000                  0.220930
# 6315  0.009874  0.002136                 0.593548                  0.418605
# 6381  0.006003  0.000777                 0.406452                  0.244186
# 6588  1.000000  0.173706                 0.574194                  0.453488
# 7299  0.009540  0.000194                 0.225806                  0.302326
# 520   0.007605  0.049131                 0.638710                  0.558140
# 6508  0.007371  0.001748                 0.470968                  0.593023
# 5392  0.014512  0.005437                 0.677419                  0.616279
# 1112  1.000000  0.001359                 0.193548                  0.093023
# 4729  0.002206  0.569861                 0.303226                  0.372093
# 2693  0.007672  0.001068                 0.296774                  0.174419
# 3857  1.000000  0.001068                 0.309677                  0.232558
# 4991  0.003701  0.070007                 0.341935                  0.348837
# 592   0.003500  0.000194                 0.445161                  0.186047

# %%
train_X_y[train_X_y['diet']==3].sample(25)
# Out:
#            age  cholesterol  heart_rate  diabetes  family_history  smoking  \
# 3400  0.494382      0.49978    0.048579        -1              -1       -1
# 5378  0.550562      0.49978    0.048579        -1              -1       -1
# 8158  0.370787      0.49978    0.045830        -1              -1       -1
# 6315  0.438202      0.49978    0.053162        -1              -1       -1
# 4259  0.550562      0.49978    0.091659        -1              -1       -1
# 7147  0.404494      0.49978    0.054995        -1              -1       -1
# 2961  0.550562      0.49978    0.086159        -1              -1       -1
# 16    0.449438      0.49978    0.063245        -1              -1       -1
# 4256  0.460674      0.49978    0.093492        -1              -1       -1
# 3634  0.292135      0.49978    0.040330        -1              -1       -1
# 4765  0.685393      0.49978    0.041247        -1              -1       -1
# 7219  0.280899      0.49978    0.035747        -1              -1       -1
# 8509  0.651685      0.49978    0.036664        -1              -1       -1
# 4887  0.573034      0.49978    0.096242        -1              -1       -1
# 7270  0.539326      0.49978    0.090742        -1              -1       -1
# 415   0.415730      0.49978    0.056829        -1              -1       -1
# 5027  0.550562      0.49978    0.044913        -1              -1       -1
# 6126  0.550562      0.49978    0.038497        -1              -1       -1
# 7521  0.382022      0.49978    0.105408        -1              -1       -1
# 897   0.404494      0.49978    0.069661        -1              -1       -1
# 2938  0.494382      0.49978    0.048579        -1              -1       -1
# 2132  0.629213      0.49978    0.057745        -1              -1       -1
# 5968  0.471910      0.49978    0.048579        -1              -1       -1
# 7299  0.348315      0.49978    0.088909        -1              -1       -1
# 7852  0.449438      0.49978    0.057745        -1              -1       -1
#
#       obesity  alcohol_consumption  exercise_hours_per_week  diet  ...  \
# 3400       -1                   -1                  0.50211     3  ...
# 5378       -1                   -1                  0.50211     3  ...
# 8158       -1                   -1                  0.50211     3  ...
# 6315       -1                   -1                  0.50211     3  ...
# 4259       -1                   -1                  0.50211     3  ...
# 7147       -1                   -1                  0.50211     3  ...
# 2961       -1                   -1                  0.50211     3  ...
# 16         -1                   -1                  0.50211     3  ...
# 4256       -1                   -1                  0.50211     3  ...
# 3634       -1                   -1                  0.50211     3  ...
# 4765       -1                   -1                  0.50211     3  ...
# 7219       -1                   -1                  0.50211     3  ...
# 8509       -1                   -1                  0.50211     3  ...
# 4887       -1                   -1                  0.50211     3  ...
# 7270       -1                   -1                  0.50211     3  ...
# 415        -1                   -1                  0.50211     3  ...
# 5027       -1                   -1                  0.50211     3  ...
# 6126       -1                   -1                  0.50211     3  ...
# 7521       -1                   -1                  0.50211     3  ...
# 897        -1                   -1                  0.50211     3  ...
# 2938       -1                   -1                  0.50211     3  ...
# 2132       -1                   -1                  0.50211     3  ...
# 5968       -1                   -1                  0.50211     3  ...
# 7299       -1                   -1                  0.50211     3  ...
# 7852       -1                   -1                  0.50211     3  ...
#
#       physical_activity_days_per_week  sleep_hours_per_day  \
# 3400                               -1                  0.5
# 5378                               -1                  0.5
# 8158                               -1                  0.5
# 6315                               -1                  0.5
# 4259                               -1                  0.5
# 7147                               -1                  0.5
# 2961                               -1                  0.5
# 16                                 -1                  0.5
# 4256                               -1                  0.5
# 3634                               -1                  0.5
# 4765                               -1                  0.5
# 7219                               -1                  0.5
# 8509                               -1                  0.5
# 4887                               -1                  0.5
# 7270                               -1                  0.5
# 415                                -1                  0.5
# 5027                               -1                  0.5
# 6126                               -1                  0.5
# 7521                               -1                  0.5
# 897                                -1                  0.5
# 2938                               -1                  0.5
# 2132                               -1                  0.5
# 5968                               -1                  0.5
# 7299                               -1                  0.5
# 7852                               -1                  0.5
#
#       heart_attack_risk_(binary)  blood_sugar     ck-mb  troponin  gender  \
# 3400                           0     0.110672  0.005536  0.004855       1
# 5378                           0     0.308300  0.081150  0.002039       1
# 8158                           0     0.092885  0.010041  0.091174       1
# 6315                           0     0.221344  0.009874  0.002136       1
# 4259                           0     0.128458  0.327547  0.002913       1
# 7147                           0     0.148221  0.014312  0.000194       1
# 2961                           0     0.326087  0.010107  0.000680       0
# 16                             0     0.233202  0.026692  0.000777       1
# 4256                           0     0.120553  0.011809  0.000388       1
# 3634                           0     0.130435  0.021053  0.000194       1
# 4765                           0     0.207510  0.004401  0.000777       1
# 7219                           0     0.280632  0.009907  0.000194       1
# 8509                           0     0.239130  0.055790  0.060783       1
# 4887                           0     0.199605  0.003901  0.001068       0
# 7270                           0     0.083004  0.004902  0.000194       1
# 415                            0     0.140316  0.004435  0.001748       1
# 5027                           0     0.247036  0.004268  0.000194       0
# 6126                           0     0.466403  0.001121  0.001942       0
# 7521                           0     0.128458  0.315234  0.000291       1
# 897                            0     0.134387  0.055489  0.000194       1
# 2938                           0     0.369565  0.004969  0.019322       1
# 2132                           0     0.181818  0.003334  0.188271       0
# 5968                           0     0.359684  0.011776  0.000388       1
# 7299                           0     0.330040  0.009540  0.000194       1
# 7852                           0     0.456522  0.005135  0.001068       1
#
#       systolic_blood_pressure  diastolic_blood_pressure    id
# 3400                 0.612903                  0.616279  9427
# 5378                 0.322581                  0.348837  9619
# 8158                 0.541935                  0.430233  9537
# 6315                 0.593548                  0.418605  9469
# 4259                 0.483871                  0.558140  9430
# 7147                 0.212903                  0.116279  9414
# 2961                 0.561290                  0.569767  9434
# 16                   0.393548                  0.255814  9528
# 4256                 0.529032                  0.616279  9431
# 3634                 0.612903                  0.406977  9595
# 4765                 0.270968                  0.174419  9445
# 7219                 0.638710                  0.383721  9631
# 8509                 0.729032                  0.779070  9506
# 4887                 0.174194                  0.209302  9496
# 7270                 0.309677                  0.430233  9637
# 415                  0.470968                  0.593023  9625
# 5027                 0.651613                  0.697674  9499
# 6126                 0.380645                  0.279070  9520
# 7521                 0.212903                  0.209302  9380
# 897                  0.258065                  0.325581  9384
# 2938                 0.374194                  0.302326  9428
# 2132                 0.251613                  0.174419  9558
# 5968                 0.374194                  0.372093  9435
# 7299                 0.225806                  0.302326  9648
# 7852                 0.567742                  0.569767  9606
#
# [25 rows x 27 columns]

# %% [markdown]
# В этих данных (только с диетой номер 3) очень много дублирующихся значений в параметрах: значение холестирола, упражнения в неделю, сидячие часы в день, зарплата, триглицериды и ИМТ. Как уже упоминалось выше - скорее всего это связано с каким-то особенным сбором данных. И диета номер 3 связана с какой-то измененной формулировкой, но не смыслом и может на самом деле быть диетой 0 или другой из имеющихся. Либо же, такое выделение диеты говорит о том что данные собирали в каком-то определенном месте среди каких-то пациентов с особенностями питания (например, проживающих в санатории), поэтому данные заполнены так однообразно. В любом случае, эти данные мы не будем менять или исключать.

# %% [markdown]
# ### Анамнез сердечных проблем

# %%
categ_pieplot(train_X_y, 'previous_heart_problems', 'Предыдущие проблемы с сердцем')
# Out:
# previous_heart_problems
# -1     241
#  0    4260
#  1    4182
# Name: id, dtype: int64

# %%
train_X_y.pivot_table(index='previous_heart_problems', columns='heart_attack_risk_(binary)', values='id', aggfunc='count')
# Out:
# heart_attack_risk_(binary)       0       1
# previous_heart_problems
# -1                           241.0     NaN
#  0                          2743.0  1517.0
#  1                          2686.0  1496.0

# %% [markdown]
# Как видно по диаграмме, пациентов с диагностированными ранее проблемами с сердцем примерно столько же, сколько не имевших проблем с сердцем. Стойкого влияния на риск сердечного приступа не замечено по сводной таблице. Этот признак не будем считать утечкой.

# %% [markdown]
# ### Использование медикаментов

# %%
categ_pieplot(train_X_y, 'medication_use', 'Использование медикаментов')
# Out:
# medication_use
# -1     241
#  0    4211
#  1    4231
# Name: id, dtype: int64

# %%
train_X_y.pivot_table(index='previous_heart_problems', columns='medication_use', values='id', aggfunc='count')
# Out:
# medication_use              -1       0       1
# previous_heart_problems
# -1                       241.0     NaN     NaN
#  0                         NaN  2155.0  2105.0
#  1                         NaN  2056.0  2126.0

# %%
train_X_y.pivot_table(index='medication_use', columns='heart_attack_risk_(binary)', values='id', aggfunc='count')
# Out:
# heart_attack_risk_(binary)       0       1
# medication_use
# -1                           241.0     NaN
#  0                          2709.0  1502.0
#  1                          2720.0  1511.0

# %% [markdown]
# Соотношение пациентов, использующих медикаменты и не использующих - примерно пополам. При этом нет заметной связи с имеющимися в анамнезе сердечными проблемами, либо с риском сердечного приступа.

# %% [markdown]
# ### Уровень стресса

# %%
col_count(train_X_y, 'stress_level', 'Уровень стресса', 'уровень')
# Out:
# Уровень стресса - описательная статистика:
# count    8683.000000
# mean        5.313141
# std         3.022292
# min        -1.000000
# 25%         3.000000
# 50%         5.000000
# 75%         8.000000
# max        10.000000
# Name: stress_level, dtype: float64
# Уникальные значения (11):
# stress_level
# -1     241
#  1     840
#  2     854
#  3     841
#  4     857
#  5     833
#  6     828
#  7     869
#  8     844
#  9     852
#  10    824
# Name: count, dtype: int64

# %% [markdown]
# ### Часы сидения в день

# %%
col_hist(train_X_y, 'sedentary_hours_per_day', 'Часы сидя', 'Время, масштаб.')
# Out:
# Часы сидя - описательная статистика:
# count    8683.000000
# mean        0.499164
# std         0.285373
# min         0.000000
# 25%         0.255741
# 50%         0.499920
# 75%         0.744623
# max         1.000000
# Name: sedentary_hours_per_day, dtype: float64

# %% [markdown]
# Снова достаточно равномерное распределение с одной пиковой точкой на значении 0,49992. Это те самые значения, которые мы видели дублирующимися в пункте по диете, ожидаемый результат.

# %% [markdown]
# ### Доход

# %%
col_hist(train_X_y, 'income', 'Доход', 'масштабировнное значение')
# Out:
# Доход - описательная статистика:
# count    8683.000000
# mean        0.496055
# std         0.284731
# min         0.000000
# 25%         0.251883
# 50%         0.494889
# 75%         0.741073
# max         1.000000
# Name: income, dtype: float64

# %% [markdown]
# Аналогично предыдущему пункту - один пик, который вызван вливанием данных с отличающегося источника.

# %% [markdown]
# ### ИМТ

# %%
col_hist(train_X_y, 'bmi', 'Индекс массы тела', 'ИМТ, масштабировнное значение')
# Out:
# Индекс массы тела - описательная статистика:
# count    8683.000000
# mean        0.496774
# std         0.282594
# min         0.000000
# 25%         0.254165
# 50%         0.494774
# 75%         0.737021
# max         1.000000
# Name: bmi, dtype: float64

# %% [markdown]
# Опять тот же пик из-за одинаковых значений и относительно равномерное распределение остальных.

# %% [markdown]
# ### Триглицериды

# %%
col_hist(train_X_y, 'triglycerides', 'Триглицериды', 'масштабировнное значение')
# Out:
# Триглицериды - описательная статистика:
# count    8683.000000
# mean        0.505485
# std         0.286353
# min         0.000000
# 25%         0.263636
# 50%         0.503603
# 75%         0.750649
# max         1.000000
# Name: triglycerides, dtype: float64

# %% [markdown]
# Опять то же распределение с одним пиком основным из-за дубликатов.

# %% [markdown]
# ### Физическая активность

# %%
col_count(train_X_y, 'physical_activity_days_per_week', 'Физическая активность д/нед.', 'дней в неделю, масштабировнное значение')
# Out:
# Физическая активность д/нед. - описательная статистика:
# count    8683.000000
# mean        3.383163
# std         2.368646
# min        -1.000000
# 25%         1.000000
# 50%         3.000000
# 75%         5.000000
# max         7.000000
# Name: physical_activity_days_per_week, dtype: float64
# Уникальные значения (9):
# physical_activity_days_per_week
# -1     241
#  0    1006
#  1    1069
#  2    1087
#  3    1091
#  4    1025
#  5    1046
#  6    1055
#  7    1063
# Name: count, dtype: int64

# %% [markdown]
# Значения очень близки. Опять выделяются 241 значение без данных.

# %% [markdown]
# ### Сон

# %%
col_count(train_X_y, 'sleep_hours_per_day', 'Сон', 'часы/сутки, масштаб.')
# Out:
# Сон - описательная статистика:
# count    8683.000000
# mean        0.503665
# std         0.327662
# min         0.000000
# 25%         0.170000
# 50%         0.500000
# 75%         0.830000
# max         1.000000
# Name: sleep_hours_per_day, dtype: float64
# Уникальные значения (7):
# sleep_hours_per_day
# 0.00    1153
# 0.17    1231
# 0.33    1200
# 0.50    1449
# 0.67    1252
# 0.83    1137
# 1.00    1261
# Name: count, dtype: int64

# %% [markdown]
# Часы сна распределены волннобразно, выбросов нет.

# %% [markdown]
# ### Риск сердечного приступа (целевой)

# %%
categ_pieplot(train_X_y, 'heart_attack_risk_(binary)', 'Риск сердечного приступа')
# Out:
# heart_attack_risk_(binary)
# 0    5670
# 1    3013
# Name: id, dtype: int64

# %% [markdown]
# Признак бинарный, у 65% наблюдаемых нет риска сердечного приступа. У 35% такой риск присутствует. Корреляцию с другими признаками посмотрим в корреляционном анализе далее.

# %% [markdown]
# ### Сахар в крови

# %%
col_hist(train_X_y, 'blood_sugar', 'Сахар в крови', 'сахар, масштабировнное значение')
# Out:
# Сахар в крови - описательная статистика:
# count    8683.000000
# mean        0.227357
# std         0.076630
# min         0.000000
# 25%         0.227018
# 50%         0.227018
# 75%         0.227018
# max         1.000000
# Name: blood_sugar, dtype: float64

# %%
train_X_y.query('blood_sugar > 0.227 & blood_sugar < 0.2271')
# Out:
#            age  cholesterol  heart_rate  diabetes  family_history  smoking  \
# 0     0.359551     0.732143    0.074244         1               1        1
# 2     0.606742     0.860714    0.055912         1               0        1
# 3     0.730337     0.007143    0.053162         0               0        1
# 4     0.775281     0.757143    0.021998         0               0        1
# 5     0.168539     0.764286    0.057745         0               1        1
# ...        ...          ...         ...       ...             ...      ...
# 8678  0.314607     0.142857    0.082493         1               0        1
# 8679  0.651685     0.253571    0.020165         1               1        1
# 8682  0.471910     0.067857    0.023831         1               0        1
# 8683  0.595506     0.000000    0.075160         0               1        1
# 8684  0.292135     0.342857    0.021082         0               1        1
#
#       obesity  alcohol_consumption  exercise_hours_per_week  diet  ...  \
# 0           1                    1                 0.535505     1  ...
# 2           1                    1                 0.944001     2  ...
# 3           0                    1                 0.697023     0  ...
# 4           0                    1                 0.412878     1  ...
# 5           1                    1                 0.082682     1  ...
# ...       ...                  ...                      ...   ...  ...
# 8678        0                    0                 0.932011     2  ...
# 8679        1                    1                 0.609064     1  ...
# 8682        0                    1                 0.076336     2  ...
# 8683        0                    1                 0.371759     2  ...
# 8684        1                    0                 0.567079     0  ...
#
#       physical_activity_days_per_week  sleep_hours_per_day  \
# 0                                   3                 0.33
# 2                                   2                 1.00
# 3                                   0                 0.33
# 4                                   5                 1.00
# 5                                   6                 0.83
# ...                               ...                  ...
# 8678                                7                 0.33
# 8679                                7                 0.83
# 8682                                1                 0.83
# 8683                                4                 0.50
# 8684                                5                 0.83
#
#       heart_attack_risk_(binary)  blood_sugar     ck-mb  troponin  gender  \
# 0                              0     0.227018  0.048229  0.036512       1
# 2                              0     0.227018  0.048229  0.036512       0
# 3                              1     0.227018  0.048229  0.036512       0
# 4                              1     0.227018  0.048229  0.036512       1
# 5                              0     0.227018  0.048229  0.036512       1
# ...                          ...          ...       ...       ...     ...
# 8678                           0     0.227018  0.048229  0.036512       0
# 8679                           1     0.227018  0.048229  0.036512       1
# 8682                           0     0.227018  0.048229  0.036512       1
# 8683                           0     0.227018  0.048229  0.036512       1
# 8684                           0     0.227018  0.048229  0.036512       1
#
#       systolic_blood_pressure  diastolic_blood_pressure    id
# 0                    0.212903                  0.709302  2664
# 2                    0.238710                  0.220930  5379
# 3                    0.348387                  0.267442  8222
# 4                    0.619355                  0.441860  4047
# 5                    0.464516                  0.418605  5817
# ...                       ...                       ...   ...
# 8678                 0.664516                  0.511628   466
# 8679                 0.361290                  0.500000  6265
# 8682                 0.374194                  0.558140  5390
# 8683                 0.477419                  0.744186   860
# 8684                 0.703226                  0.639535  7270
#
# [6551 rows x 27 columns]

# %% [markdown]
# Подавляющее число значений равны друг другу - больше 6500 вхождений одного и того же значения. От этого boxplot выявил огромное количество выбросов (все остальные значения, по сути). Сахар в крови - достаточно важный показатель для оценки здоровья организма и нагрузки на сердце. Однако, такое количество одинаковых значений может оказаться бесполезным. Вполне возможно, что даже такоое однообразие значений может быть результативным, но именно в сочетании с другими параметрами (например, наличие диабета, как самая очевидная связь). Посмотрим внимательно на корреляционном анализе, прежде чем принимать решение по поводу необходимости таких данных.

# %% [markdown]
# ### Креатинкиназа MB

# %%
col_hist(train_X_y, 'ck-mb', 'Креатинкиназа MB', 'креатинкиназа, масштабировнное значение')
# Out:
# Креатинкиназа MB - описательная статистика:
# count    8683.000000
# mean        0.048168
# std         0.075537
# min         0.000000
# 25%         0.048229
# 50%         0.048229
# 75%         0.048229
# max         1.000000
# Name: ck-mb, dtype: float64

# %% [markdown]
# Так же, как и в сахаре - огромное значение одинаковых значений. Скорее всего, это даже одни и те же записи. Сам параметр характеризует повреждение сердечной мышцы и используется для диагноза инфаркта миакарда. В данном проекте эта характеристика будет считаться утечкой данных, поэтому ее будет необходимо удалить. Сделаем это после корреляционного анализа.

# %% [markdown]
# ### Тропонин

# %%
col_hist(train_X_y, 'troponin', 'Тропонин', 'тропонин, масштабировнное значение')
# Out:
# Тропонин - описательная статистика:
# count    8683.000000
# mean        0.036697
# std         0.060161
# min         0.000000
# 25%         0.036512
# 50%         0.036512
# 75%         0.036512
# max         1.000000
# Name: troponin, dtype: float64

# %% [markdown]
# Аналогично - огромный пик на одном и том же значении в 6500+ значений. И, как и кретинкиназа, это снова анализ, связанный с диагностикой инфаркта, а значит - утечка данных.

# %% [markdown]
# ### Пол

# %%
categ_pieplot(train_X_y, 'gender', 'Распределение пола')
# Out:
# gender
# 0    2645
# 1    6038
# Name: id, dtype: int64

# %% [markdown]
# Среди данных присутствует неравномерность: мужчин 70%, а женщин 30%, отличие больше чем в два раза.

# %% [markdown]
# ### Систолическое (верхнее) артериальное давление

# %%
col_hist(train_X_y, 'systolic_blood_pressure', 'Систолическое артериальное давление', 'давление, масштабировнное значение')
# Out:
# Систолическое артериальное давление - описательная статистика:
# count    8683.000000
# mean        0.450286
# std         0.170203
# min         0.000000
# 25%         0.303226
# 50%         0.445161
# 75%         0.600000
# max         1.000000
# Name: systolic_blood_pressure, dtype: float64

# %% [markdown]
# Большая часть значений находится между 0,15 и 0,75. Присутствуют редкие значения ниже и выше этого диапазона.

# %% [markdown]
# ### Диастолическое (нижнее) артериальное давление

# %%
col_hist(train_X_y, 'diastolic_blood_pressure', 'Диастолическое артериальное давление', 'давление, масштабировнное значение')
# Out:
# Диастолическое артериальное давление - описательная статистика:
# count    8683.000000
# mean        0.497607
# std         0.171841
# min         0.000000
# 25%         0.348837
# 50%         0.500000
# 75%         0.651163
# max         1.000000
# Name: diastolic_blood_pressure, dtype: float64

# %% [markdown]
# Диастолическое давление распределено подобно систолическому - с редкими значениями скраю от основного столба значений. Такие единичные значения выглядят немного сомнительно, но даже если это ошибочные значения - они не должны очень сильно влиять на модель при таком большом количестве записей. Поэтому оставим их.

# %% [markdown]
# ### Корреляционный анализ

# %%
interval_cols = ['age', 'cholesterol', 'heart_rate', 'exercise_hours_per_week', 'sedentary_hours_per_day', 'income',
'bmi', 'triglycerides', 'blood_sugar', 'ck-mb',	'troponin', 'systolic_blood_pressure', 'diastolic_blood_pressure']
phik_overview = train_X_y.drop('id', axis=1).phik_matrix(interval_cols=interval_cols)
print(phik_overview.shape)
# Out:
# (26, 26)

# %%
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'correlation $\phi_K$',
    fontsize_factor=0.9,
    figsize=(15, 10)
)

# %% [markdown]
# У целевого признака не наблюдается сильной корреляции с параметрами. Самая заметная - с диетой и уровнем стресса. Не наблюдается ожидаемой корреляции с тропонином, ck-mb и сахаром.
#
# Наблюдается большая мультиколлениарность. Помня про наличие кучи дубликатов с диетой №3, попробуем убрать эти данные и посмотреть на матрицу без них.

# %%
interval_cols = ['age', 'cholesterol', 'heart_rate', 'exercise_hours_per_week', 'sedentary_hours_per_day', 'income',
'bmi', 'triglycerides', 'blood_sugar', 'ck-mb',	'troponin', 'systolic_blood_pressure', 'diastolic_blood_pressure']
train_no3 = train_X_y[train_X_y['diet']!=3]
phik_overview = train_no3.drop('id', axis=1).phik_matrix(interval_cols=interval_cols)
print(phik_overview.shape)
# Out:
# (26, 26)

# %%
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'correlation $\phi_K$',
    fontsize_factor=0.9,
    figsize=(15, 10)
)

# %% [markdown]
# Без вброшенных данных с множеством копий матрица выглядит совершненно по-другому. У целевого признака нет заметной корреляции ни с одним признаком. Есть корреляция между полом и курением, но оставим эти данные. Так же есть корреляция между курением и возрастом. Средняя корреляция между сахаром и 4 характеристиками: пульс, возраст, тропонин и ck-mb.
#
# Уберем утечку данных из признаков (тропонин и ck-mb), уберем ненужные признаки: лоя начала уберем только доход. Если модель будет показывать слишком низкую метрику, попробуем убрать и какие-то другие признаки.
#
# Добавим обратно несколько значений с диетой №3, так как модель нужно обучить и на этот параметр.

# %%
diet_3_records = train_X_y[train_X_y['diet'] == 3]
records_to_keep = diet_3_records.sample(n=5, random_state=42)
train_X_y_new = train_X_y.drop(diet_3_records.index.difference(records_to_keep.index))
train_X_y_new = train_X_y_new.drop(['troponin', 'ck-mb', 'income', 'id', 'smoking'], axis=1)
train_X_y_new.head()
# Out:
#         age  cholesterol  heart_rate  diabetes  family_history  obesity  \
# 0  0.359551     0.732143    0.074244         1               1        1
# 1  0.202247     0.325000    0.047663         1               1        0
# 2  0.606742     0.860714    0.055912         1               0        1
# 3  0.730337     0.007143    0.053162         0               0        0
# 4  0.775281     0.757143    0.021998         0               0        0
#
#    alcohol_consumption  exercise_hours_per_week  diet  \
# 0                    1                 0.535505     1
# 1                    1                 0.068690     2
# 2                    1                 0.944001     2
# 3                    1                 0.697023     0
# 4                    1                 0.412878     1
#
#    previous_heart_problems  ...  sedentary_hours_per_day       bmi  \
# 0                        1  ...                 0.225704  0.459176
# 1                        1  ...                 0.289923  0.117053
# 2                        1  ...                 0.550133  0.373574
# 3                        0  ...                 0.330962  0.049735
# 4                        0  ...                 0.524600  0.830405
#
#    triglycerides  physical_activity_days_per_week  sleep_hours_per_day  \
# 0       0.979221                                3                 0.33
# 1       0.515584                                3                 0.83
# 2       0.012987                                2                 1.00
# 3       0.131169                                0                 0.33
# 4       0.070130                                5                 1.00
#
#    heart_attack_risk_(binary)  blood_sugar  gender  systolic_blood_pressure  \
# 0                           0     0.227018       1                 0.212903
# 1                           0     0.150198       0                 0.412903
# 2                           0     0.227018       0                 0.238710
# 3                           1     0.227018       0                 0.348387
# 4                           1     0.227018       1                 0.619355
#
#    diastolic_blood_pressure
# 0                  0.709302
# 1                  0.569767
# 2                  0.220930
# 3                  0.267442
# 4                  0.441860
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Выводы
# Мы провели ииследовательский анализ полученных данных. Большинство из них - масштабированные данные, остальные - категориальные. Масштабированные данные придется масшабировать заново, так как часть из них имели выбросы, от которых пришлось избравиться.
#
# В данных имелось сливание различных баз, о чем заметно говорили 241 запись с диетой № 3 и множеством дубликатов в параметрах. Такие данные давали большое искажение на матрице корреляции и очень бросались в глаза на графиках, поэтому мы избавились от большинства этих данных, оставили только 5 вхождений для обучения модели.
#
# Далее мы выполним предподготовку данных и обучим модели.

# %% [markdown]
# ## Обучение модели

# %% [markdown]
# ### Предподготовка данных

# %%
#Разделим на выборки

X_train, X_test, y_train, y_test = train_test_split(
    train_X_y_new.drop(['heart_attack_risk_(binary)'], axis=1),
    train_X_y_new['heart_attack_risk_(binary)'],
    test_size = TEST_SIZE, 
    random_state = RANDOM_STATE,
    stratify = train_X_y_new['heart_attack_risk_(binary)'])

X_train.shape, X_test.shape
# Out:
# ((6335, 21), (2112, 21))

# %%
# Создаем кастомную метрику F2
f2_scorer = make_scorer(fbeta_score, beta=2)

# %%
ohe_columns = ['diabetes', 'family_history', 'obesity',
               'alcohol_consumption', 'previous_heart_problems', 'medication_use', 'gender']
ord_columns = ['diet', 'stress_level', 'physical_activity_days_per_week', 'sleep_hours_per_day']
num_columns = ['age', 'cholesterol', 'heart_rate', 'exercise_hours_per_week',
               'sedentary_hours_per_day', 'bmi', 'triglycerides', 'blood_sugar',
               'systolic_blood_pressure', 'diastolic_blood_pressure']

# %%
ohe_pipe = Pipeline(
    [
     ('ohe', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
    ]
    )

# %%
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', StandardScaler(), ord_columns),
     ('num', StandardScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %%
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', None)
])

# %%
param_grid = [
    
    # LightGBM
    {
        'models': [LGBMClassifier(random_state=RANDOM_STATE, class_weight='balanced')],
        'models__n_estimators': [100, 200, 300],
        'models__learning_rate': [0.01, 0.05, 0.1],
        'models__max_depth': [3, 4, 5, 6],
        'models__num_leaves': [31, 50, 100],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    
    # CatBoost
    {
        'models': [CatBoostClassifier(random_state=RANDOM_STATE, verbose=0)],
        'models__iterations': [100, 200, 300],
        'models__learning_rate': [0.01, 0.05, 0.1],
        'models__depth': [4, 6, 8],
        'preprocessor__num': ['passthrough']
    },
    
    # Random Forest
    {
        'models': [RandomForestClassifier(random_state=RANDOM_STATE, class_weight='balanced')],
        'models__n_estimators': [20, 35, 50, 75, 100],
        'models__max_depth': [None, 10, 15, 20, 25, 30],
        'models__max_features': ['sqrt', 'log2', 0.5],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough'],
        'models__min_samples_split': [2, 3, 5, 7, 10]
    },

    # SVM
    {
        'models': [SVC(random_state=RANDOM_STATE, probability=True, class_weight='balanced')],
        'models__C': [0.1, 1, 10],
        'models__kernel': ['sigmoid', 'poly', 'rbf'],
        'models__degree': range(1,6),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    }
]

# %%
random_search = RandomizedSearchCV(
    pipe_final,
    param_grid,
    n_iter=50,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1,
    verbose=1
)

# %%
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('ohe',
#                                                                                                 OneHotEncoder(handle_unknown='ignore',
#                                                                                                               sparse_output=False))]),
#                                                                                ['diabetes',
#                                                                                 'family_history',
#                                                                                 'obesity',
#                                                                                 'alcohol_consumption',
#                                                                                 'previous_heart_problems',
#                                                                                 'medication_use',
#                                                                                 'gender']),
#                                                                               ('ord',
#                                                                                StandardScaler...
#                                          'models__n_estimators': [20, 35, 50,
#                                                                   75, 100],
#                                          'preprocessor__num': [StandardScaler(),
#                                                                MinMaxScaler(),
#                                                                'passthrough']},
#                                         {'models': [SVC(class_weight='balanced',
#                                                         probability=True,
#                                                         random_state=42)],
#                                          'models__C': [0.1, 1, 10],
#                                          'models__degree': range(1, 6),
#                                          'models__kernel': ['sigmoid', 'poly',
#                                                             'rbf'],
#                                          'preprocessor__num': [StandardScaler(),
#                                                                MinMaxScaler(),
#                                                                'passthrough']}],
#                    scoring='roc_auc', verbose=1)

# %%
print('Лучшая модель и её параметры:\n', random_search.best_params_)
print ('\nМетрика в результате кросс валидации:', random_search.best_score_)
# Out:
# Лучшая модель и её параметры:
#  {'preprocessor__num': StandardScaler(), 'models__n_estimators': 75, 'models__min_samples_split': 2, 'models__max_features': 0.5, 'models__max_depth': 25, 'models': RandomForestClassifier(class_weight='balanced', random_state=42)}
#
# Метрика в результате кросс валидации: 0.598118074865787

# %%
result = pd.DataFrame(random_search.cv_results_)
result.sort_values('rank_test_score').head(15)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 41       5.368540      0.288395         0.063398        0.020871
# 25       7.817996      0.168133         0.089324        0.017499
# 3        4.871107      1.497827         0.242545        0.095338
# 20       2.953617      0.123488         0.088949        0.008788
# 49       2.427294      0.262036         0.079203        0.020484
# 32       5.641489      0.359336         0.082204        0.018609
# 48       8.700235      0.664198         0.073146        0.014190
# 26       2.751088      0.146315         0.041423        0.012919
# 46       3.233870      0.360240         0.090928        0.015405
# 1        4.160015      0.281897         0.121736        0.031877
# 2        8.365152      0.870103         0.084604        0.020737
# 16       3.810655      0.191774         0.049280        0.011579
# 27       3.471067      0.217288         0.045962        0.011794
# 30       2.429193      0.086881         0.083315        0.020831
# 8        0.989502      0.037996         0.061490        0.027147
#
#    param_preprocessor__num  param_models__learning_rate  \
# 41        StandardScaler()                          NaN
# 25             passthrough                          NaN
# 3           MinMaxScaler()                          NaN
# 20             passthrough                          NaN
# 49        StandardScaler()                          NaN
# 32        StandardScaler()                          NaN
# 48        StandardScaler()                          NaN
# 26             passthrough                          NaN
# 46          MinMaxScaler()                          NaN
# 1           MinMaxScaler()                          NaN
# 2         StandardScaler()                          NaN
# 16             passthrough                          NaN
# 27             passthrough                          NaN
# 30        StandardScaler()                          NaN
# 8         StandardScaler()                          NaN
#
#     param_models__iterations  param_models__depth  \
# 41                       NaN                  NaN
# 25                       NaN                  NaN
# 3                        NaN                  NaN
# 20                       NaN                  NaN
# 49                       NaN                  NaN
# 32                       NaN                  NaN
# 48                       NaN                  NaN
# 26                       NaN                  NaN
# 46                       NaN                  NaN
# 1                        NaN                  NaN
# 2                        NaN                  NaN
# 16                       NaN                  NaN
# 27                       NaN                  NaN
# 30                       NaN                  NaN
# 8                        NaN                  NaN
#
#                                          param_models  \
# 41  RandomForestClassifier(class_weight='balanced'...
# 25  RandomForestClassifier(class_weight='balanced'...
# 3   RandomForestClassifier(class_weight='balanced'...
# 20  RandomForestClassifier(class_weight='balanced'...
# 49  RandomForestClassifier(class_weight='balanced'...
# 32  RandomForestClassifier(class_weight='balanced'...
# 48  RandomForestClassifier(class_weight='balanced'...
# 26  RandomForestClassifier(class_weight='balanced'...
# 46  RandomForestClassifier(class_weight='balanced'...
# 1   RandomForestClassifier(class_weight='balanced'...
# 2   RandomForestClassifier(class_weight='balanced'...
# 16  RandomForestClassifier(class_weight='balanced'...
# 27  RandomForestClassifier(class_weight='balanced'...
# 30  RandomForestClassifier(class_weight='balanced'...
# 8   RandomForestClassifier(class_weight='balanced'...
#
#     param_models__n_estimators  ...  param_models__C  \
# 41                        75.0  ...              NaN
# 25                       100.0  ...              NaN
# 3                         50.0  ...              NaN
# 20                       100.0  ...              NaN
# 49                        75.0  ...              NaN
# 32                        75.0  ...              NaN
# 48                       100.0  ...              NaN
# 26                        35.0  ...              NaN
# 46                       100.0  ...              NaN
# 1                        100.0  ...              NaN
# 2                         75.0  ...              NaN
# 16                        50.0  ...              NaN
# 27                        50.0  ...              NaN
# 30                       100.0  ...              NaN
# 8                         35.0  ...              NaN
#
#                                                params split0_test_score  \
# 41  {'preprocessor__num': StandardScaler(), 'model...          0.597465
# 25  {'preprocessor__num': 'passthrough', 'models__...          0.596834
# 3   {'preprocessor__num': MinMaxScaler(), 'models_...          0.599119
# 20  {'preprocessor__num': 'passthrough', 'models__...          0.602095
# 49  {'preprocessor__num': StandardScaler(), 'model...          0.607213
# 32  {'preprocessor__num': StandardScaler(), 'model...          0.604662
# 48  {'preprocessor__num': StandardScaler(), 'model...          0.608688
# 26  {'preprocessor__num': 'passthrough', 'models__...          0.597931
# 46  {'preprocessor__num': MinMaxScaler(), 'models_...          0.586381
# 1   {'preprocessor__num': MinMaxScaler(), 'models_...          0.604626
# 2   {'preprocessor__num': StandardScaler(), 'model...          0.592993
# 16  {'preprocessor__num': 'passthrough', 'models__...          0.594660
# 27  {'preprocessor__num': 'passthrough', 'models__...          0.596888
# 30  {'preprocessor__num': StandardScaler(), 'model...          0.576033
# 8   {'preprocessor__num': StandardScaler(), 'model...          0.604551
#
#     split1_test_score split2_test_score  split3_test_score  split4_test_score  \
# 41           0.613882          0.623717           0.604551           0.550975
# 25           0.608119          0.617797           0.592138           0.556885
# 3            0.595184          0.594665           0.584416           0.561734
# 20           0.565730          0.599344           0.572792           0.578488
# 49           0.569570          0.595131           0.566124           0.580047
# 32           0.561122          0.604700           0.577628           0.557376
# 48           0.556356          0.614213           0.580195           0.544273
# 26           0.592359          0.617898           0.560032           0.535480
# 46           0.573761          0.605130           0.575470           0.562309
# 1            0.588274          0.575604           0.576161           0.558327
# 2            0.567888          0.602302           0.587100           0.550050
# 16           0.569501          0.593203           0.573814           0.560478
# 27           0.550220          0.604681           0.583928           0.549826
# 30           0.560674          0.604695           0.579975           0.562966
# 8            0.570927          0.599952           0.575969           0.525324
#
#    mean_test_score  std_test_score  rank_test_score
# 41        0.598118        0.025172                1
# 25        0.594355        0.020756                2
# 3         0.587024        0.013547                3
# 20        0.583690        0.014506                4
# 49        0.583617        0.015527                5
# 32        0.581098        0.020426                6
# 48        0.580745        0.027663                7
# 26        0.580740        0.029287                8
# 46        0.580610        0.014442                9
# 1         0.580598        0.015342               10
# 2         0.580066        0.018763               11
# 16        0.578331        0.013453               12
# 27        0.577109        0.023088               13
# 30        0.576868        0.015749               14
# 8         0.575344        0.028215               15
#
# [15 rows x 26 columns]

# %%
best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test)
y_pred_proba = best_model.predict_proba(X_test)[:, 1]

# Все метрики
metrics = {
    'F2-score': fbeta_score(y_test, y_pred, beta=2),
    'F1-score': f1_score(y_test, y_pred, pos_label=0),
    'Recall': recall_score(y_test, y_pred),
    'Precision': precision_score(y_test, y_pred),
    'Accuracy': accuracy_score(y_test, y_pred),
    'ROC-AUC': roc_auc_score(y_test, y_pred_proba)
}

print("\nМетрики на тестовой выборке:")
for metric, value in metrics.items():
    print(f"{metric}: {value:.4f}")

print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=['No risk', 'Risk']))
# Out:
# Метрики на тестовой выборке:
# F2-score: 0.1390
# F1-score: 0.7796
# Recall: 0.1169
# Precision: 0.5714
# Accuracy: 0.6539
# ROC-AUC: 0.5658
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      No risk       0.66      0.95      0.78      1359
#         Risk       0.57      0.12      0.19       753
#
#     accuracy                           0.65      2112
#    macro avg       0.62      0.53      0.49      2112
# weighted avg       0.63      0.65      0.57      2112

# %%
# создание и обучение модели DummyClassifier 
dummy_model = DummyClassifier(random_state=RANDOM_STATE)
dummy_model.fit(X_train, y_train)

# предсказание на тестовых данных
dummy_model_preds = dummy_model.predict(X_test)
dummy_model_probas = dummy_model.predict_proba(X_test)[:,1]

roc = roc_auc_score(y_test, dummy_model_probas)
print('ROC-AUC =', round(roc,2))
f1 = f1_score(y_test, dummy_model_preds, pos_label=0)
print('F1-score =', round(f1,2))
# Out:
# ROC-AUC = 0.5
# F1-score = 0.78

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues_r')
plt.ylabel('True label')
plt.xlabel('Predicted');

# %%
data = pd.DataFrame(zip(y_test, y_pred_proba),
             columns = ['y_valid', 'y_proba'])

thresholds = [round(i,2) for i in np.linspace(0.1,0.5,num = 4,endpoint=False)]
print(thresholds) 
columns = []

for i in thresholds:
	columns.append('y_pred_'+str(i))
	data['y_pred_'+str(i)] = data['y_proba'].apply(lambda x: 1 if x>=i else 0)

print(data.sample(10))
# Out:
# [0.1, 0.2, 0.3, 0.4]
#       y_valid   y_proba  y_pred_0.1  y_pred_0.2  y_pred_0.3  y_pred_0.4
# 1332        0  0.446676           1           1           1           1
# 460         0  0.351789           1           1           1           0
# 458         1  0.496167           1           1           1           1
# 332         1  0.378391           1           1           1           0
# 1439        0  0.437904           1           1           1           1
# 899         1  0.320347           1           1           1           0
# 1996        0  0.439699           1           1           1           1
# 395         1  0.474129           1           1           1           1
# 377         0  0.362727           1           1           1           0
# 1050        0  0.280000           1           1           0           0

# %%
print('y_pred_0.1 F2-score = ', fbeta_score(data['y_valid'], data['y_pred_0.1'], beta=2))
print('y_pred_0.2 F2-score = ', fbeta_score(data['y_valid'], data['y_pred_0.2'], beta=2))
print('y_pred_0.3 F2-score = ', fbeta_score(data['y_valid'], data['y_pred_0.3'], beta=2))
# Out:
# y_pred_0.1 F2-score =  0.7408500590318772
# y_pred_0.2 F2-score =  0.7360254625024866
# y_pred_0.3 F2-score =  0.6568627450980392

# %%
thresholds = [0.1, 0.15, 0.17, 0.18, 0.19, 0.2, 0.21, 0.22, 0.23, 0.24, 0.25]

columns = []
for i in thresholds:
    columns.append('y_pred_'+str(i))
    data['y_pred_'+str(i)] = data['y_proba'].apply(lambda x: 1 if x>=i else 0)
    print(f'y_pred_{i} F2-score = ', fbeta_score(data['y_valid'], data[f'y_pred_{i}'], beta=2))
# Out:
# y_pred_0.1 F2-score =  0.7408500590318772
# y_pred_0.15 F2-score =  0.7434834123222749
# y_pred_0.17 F2-score =  0.7416930379746836
# y_pred_0.18 F2-score =  0.7390529027144839
# y_pred_0.19 F2-score =  0.7362877583465819
# y_pred_0.2 F2-score =  0.7360254625024866
# y_pred_0.21 F2-score =  0.7345309381237525
# y_pred_0.22 F2-score =  0.7284768211920529
# y_pred_0.23 F2-score =  0.7236576503835285
# y_pred_0.24 F2-score =  0.720072918776585
# y_pred_0.25 F2-score =  0.7151601713935931

# %%
y_new = (best_model.predict_proba(X_test)[:, 1] >= 0.18).astype(int) 
y_pred_proba_new = best_model.predict_proba(X_test)[:, 1] >= 0.18
metrics_new = {
    'F2-score': fbeta_score(y_test, y_new, beta=2),
    'F1-score': f1_score(y_test, y_new, pos_label=0),
    'Recall': recall_score(y_test, y_new),
    'Precision': precision_score(y_test, y_new),
    'Accuracy': accuracy_score(y_test, y_new),
    'ROC-AUC': roc_auc_score(y_test, y_pred_proba_new)
}
print("\nНовые метрики на тестовой выборке:")
for metric, value in metrics_new.items():
    print(f"{metric}: {value:.4f}")

cm = confusion_matrix(y_test, y_new)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues_r')
plt.ylabel('True label')
plt.xlabel('Predicted');
# Out:
# Новые метрики на тестовой выборке:
# F2-score: 0.7391
# F1-score: 0.0975
# Recall: 0.9907
# Precision: 0.3666
# Accuracy: 0.3864
# ROC-AUC: 0.5211

# %%
shap.initjs()

# Получаем лучшую модель
best_model = random_search.best_estimator_

# Подготавливаем данные для SHAP
X_test_processed = best_model.named_steps['preprocessor'].transform(X_test)
feature_names = best_model.named_steps['preprocessor'].get_feature_names_out()
X_test_shap = pd.DataFrame(X_test_processed, columns=feature_names)

# Для RandomForest используем TreeExplainer (быстрее и точнее)
explainer = shap.TreeExplainer(best_model.named_steps['models'])
shap_values = explainer.shap_values(X_test_shap)

# Визуализация важности признаков
plt.figure(figsize=(12, 8))
shap.summary_plot(shap_values, X_test_shap, plot_type="bar", show=False)
plt.title("SHAP Feature Importance - Random Forest")
plt.tight_layout()
plt.show()

# Детальная визуализация (для класса 1 - риск сердечного приступа)
plt.figure(figsize=(12, 8))
shap.summary_plot(shap_values[1], X_test_shap, show=False)
plt.title("SHAP Summary Plot - Class 1 (Heart Attack Risk)")
plt.tight_layout()
plt.show()

# Анализ конкретных наблюдений
print("Анализ SHAP значений для первых 5 наблюдений:")
for i in range(min(5, len(X_test_shap))):
    print(f"\nНаблюдение {i+1}:")
    shap.force_plot(
        explainer.expected_value[1],
        shap_values[1][i],
        X_test_shap.iloc[i],
        matplotlib=True,
        show=False
    )
    plt.title(f"SHAP Force Plot - Observation {i+1}")
    plt.tight_layout()
    plt.show()

# Текстовый вывод важности признаков
shap_importance = np.mean(np.abs(shap_values[1]), axis=0)
importance_df = pd.DataFrame({
    'feature': feature_names,
    'shap_importance': shap_importance
}).sort_values('shap_importance', ascending=False)

print("\nТоп-10 самых важных признаков по SHAP:")
print(importance_df.head(10))
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.0"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...

# %%
shap.plots.beeswarm(shap_values[:,:,1], max_display = 25)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 shap.plots.beeswarm(shap_values[:,:,1], max_display = 25)
#
# File ~\anaconda3\Lib\site-packages\shap\plots\_beeswarm.py:111, in beeswarm(shap_values, max_display, order, clustering, cluster_threshold, color, axis_color, alpha, ax, show, log_scale, color_bar, s, plot_size, color_bar_label, group_remaining_features)
#     109 if not isinstance(shap_values, Explanation):
#     110     emsg = "The beeswarm plot requires an `Explanation` object as the `shap_values` argument."
# --> 111     raise TypeError(emsg)
#     113 sv_shape = shap_values.shape
#     114 if len(sv_shape) == 1:
#
# TypeError: The beeswarm plot requires an `Explanation` object as the `shap_values` argument.

# %%
shap.plots.bar(shap_values[:,:,1], max_display = 25)

# %%
#влияние признаков на примере первого элемента
shap.plots.waterfall(shap_values[0,:,1], max_display = 25)
